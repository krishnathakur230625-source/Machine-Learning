# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data -O /content/Automobile_data.csv
# Out:
# --2026-05-07 07:02:27--  https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘/content/Automobile_data.csv’
#
# /content/Automobile     [ <=>                ]  25.33K  --.-KB/s    in 0.03s
#
# 2026-05-07 07:02:27 (965 KB/s) - ‘/content/Automobile_data.csv’ saved [25936]

# %% [markdown]
# use AUTOMOBILE DATASET

# %% [markdown]
# # New Section

# %% [markdown]
# Question 1: From given data set print first and last five rows

# %%
import pandas as pd
# The UCI dataset does not have headers, so we define them based on the dataset description
headers = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
df = pd.read_csv('/content/Automobile_data.csv', names=headers)
# Rename 'make' to 'company' to match your existing code logic
df.rename(columns={'make': 'company'}, inplace=True)
display(df.head(5))
# Out:
#    symboling normalized-losses      company fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
df.tail(5)

# %% [markdown]
# Question 2: Clean data and update the CSV file
# Replace all column values which contain ‘?’ and n.a with NaN.

# %%
# Re-loading with na_values
df = pd.read_csv("/content/Automobile_data.csv", names=headers, na_values=["?","n.a"])
df.rename(columns={'make': 'company'}, inplace=True)

print(df.head())
# Fix: Save to a valid Colab path instead of D:\
df.to_csv("/content/Automobile_data_cleaned.csv", index=False)
# Out:
#    symboling  normalized-losses      company fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# Question 3: Find the most expensive car company name
# Print most expensive car’s company name and price.

# %%
# Question 3: Find the most expensive car company name
# The price column is currently an object/string due to '?', we need to ensure it's numeric
df['price'] = pd.to_numeric(df['price'], errors='coerce')
most_expensive = df[['company', 'price']][df.price == df['price'].max()]
most_expensive
# Out:
#           company    price
# 74  mercedes-benz  45400.0

# %%
Question 4: Print All Toyota Cars details

# %%
# Question 4: Print All Toyota Cars details
toyota_df = df[df['company'] == 'toyota']
toyota_df
# Out:
#      symboling  normalized-losses company fuel-type aspiration num-of-doors  \
# 150          1               87.0  toyota       gas        std          two
# 151          1               87.0  toyota       gas        std          two
# 152          1               74.0  toyota       gas        std         four
# 153          0               77.0  toyota       gas        std         four
# 154          0               81.0  toyota       gas        std         four
# 155          0               91.0  toyota       gas        std         four
# 156          0               91.0  toyota       gas        std         four
# 157          0               91.0  toyota       gas        std         four
# 158          0               91.0  toyota    diesel        std         four
# 159          0               91.0  toyota    diesel        std         four
# 160          0               91.0  toyota       gas        std         four
# ...

# %%
Question 5: Count total cars per company

# %%
# Question 5: Count total cars per company
df['company'].value_counts()
# Out:
# company
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
Question 6: Find each company’s Higesht price car
# Out:
#   File "/tmp/ipykernel_669/3324478930.py", line 1
#     Question 6: Find each company’s Higesht price car
#                                  ^
# SyntaxError: invalid character '’' (U+2019)

# %%
# Question 6: Find each company’s Highest price car
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers[['company', 'price']].max()
priceDf
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  23875.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# isuzu                  isuzu  11048.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mercury              mercury  16503.0
# mitsubishi        mitsubishi  14869.0
# nissan                nissan  19699.0
# peugot                peugot  18150.0
# plymouth            plymouth  12764.0
# porsche              porsche  37028.0
# renault              renault   9895.0
# saab                    saab  18620.0
# subaru                subaru  11694.0
# toyota                toyota  17669.0
# volkswagen        volkswagen  13845.0
# volvo                  volvo  22625.0

# %%
Question 7: Find the average mileage of each car making company

# %%
# Question 7: Find the average mileage of each car making company
# Note: Using 'city-mpg' as the mileage metric
car_Manufacturers = df.groupby('company')
mileageDf = car_Manufacturers['city-mpg'].mean()
mileageDf
# Out:
# company
# alfa-romero      20.333333
# audi             18.857143
# bmw              19.375000
# chevrolet        41.000000
# dodge            28.000000
# honda            30.384615
# isuzu            31.000000
# jaguar           14.333333
# mazda            25.705882
# mercedes-benz    18.500000
# mercury          19.000000
# mitsubishi       24.923077
# nissan           27.000000
# peugot           22.454545
# plymouth         28.142857
# porsche          17.400000
# renault          23.000000
# saab             20.333333
# subaru           26.333333
# toyota           27.500000
# volkswagen       28.583333
# volvo            21.181818
# Name: city-mpg, dtype: float64

# %%
Question 8: Sort all cars by Price column

# %%
# Question 8: Sort all cars by Price column
carsDf = df.sort_values(by=['price'], ascending=False)
carsDf.head(5)
# Out:
#      symboling  normalized-losses        company fuel-type aspiration  \
# 74           1                NaN  mercedes-benz       gas        std
# 16           0                NaN            bmw       gas        std
# 73           0                NaN  mercedes-benz       gas        std
# 128          3                NaN        porsche       gas        std
# 17           0                NaN            bmw       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 74           two      hardtop          rwd           front       112.0  ...
# 16           two        sedan          rwd           front       103.5  ...
# 73          four        sedan          rwd           front       120.9  ...
# 128          two  convertible          rwd            rear        89.5  ...
# 17          four        sedan          rwd           front       110.0  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
Question 9: Concatenate two data frames using following conditions

    Create two data frames using following two Dicts, Concatenate those two data frame and create a key for each data frame.

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
# Question 9: Concatenate two data frames
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)
carsDf2 = pd.DataFrame.from_dict(japaneseCars)

carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %%
Question 10: Merge two data frames using following condition
    Create two data frames using following two Dicts, Merge two data frames, and append second data frame as a new column to first data frame.

Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
import pandas as pd
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
carPriceDf = pd.DataFrame.from_dict(Car_Price)
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)
carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf
